# %% [markdown]
# Name: Antony Krymski
#
# Username: agk-123

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv1D, Conv2D, Flatten, Dense, LSTM, Reshape, MaxPooling2D, LayerNormalization, TimeDistributed, GRU, Lambda, BatchNormalization, LeakyReLU, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

plt.style.use("bmh")
plt.rcParams.update({'font.size': 10})

def scale(a):
    # minmax scaling 
    maxv = np.max(a, axis=0)
    minv = np.min(a, axis=0)
    return (a - minv) / (maxv - minv) * 2. - 1.

def split(X, y, test_size=0.33):
    # timeseries split 
    i = int(np.floor(len(X) * (1 - test_size)))
    X_train, y_train = X[:i], y[:i]
    X_test, y_test = X[i:], y[i:]
    return X_train, X_test, y_train, y_test

def window(data, timesteps, strides=1):
    # windowing data 
    x = []
    for i in range(0, len(data) - timesteps, strides):
        x.append(data[i:i+timesteps])
    return np.array(x)

def download(ticker='^GSPC'):
    url = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1=0&period2=9999999999&interval=1d&events=history&includeAdjustedClose=true'
    return pd.read_csv(url, index_col='Date', parse_dates=True)

def plot(x):
    plt.figure(figsize=(16, 2))
    plt.margins(x=0, y=0)
    plt.plot(x)
    plt.show()

def plot_forecast(x, y, y_pred):
    t1 = np.arange(0, len(x), 1)
    t2 = np.arange(len(x), len(x) + len(y), 1)
    fig, ax = plt.subplots(figsize=(16, 2))
    ax.margins(x=0, y=0)
    ax.plot(t1, x, color='blue')
    ax.plot(t2, y, color='blue', label='Actual')
    ax.plot(t2, y_pred, color='red', label='Forecast')
    ax.axvline(x=len(x), color='gray', linestyle='--')
    ax.legend(loc='lower left')
    plt.tight_layout()
    plt.show()

def plot_timeseries(**kwargs):
    fig, (ax) = plt.subplots(1, 1, sharex=True, figsize=(16, 2))
    ax.margins(x=0, y=0)
    index = kwargs['index'] if 'index' in kwargs else None
    for key, value in kwargs.items():
        if key == 'title':
            ax.set_title(value)
        elif key == 'index':
            pass
        else:
            if index is None:
                ax.plot(value, label=key)
            else:
                ax.plot(index, value, label=key)
    plt.legend(loc='lower left')
    plt.tight_layout()
    plt.show()

def plot_training(history, metric='loss'):
    plot_timeseries(index=range(history.params['epochs']), title=metric, train=history.history[metric], test=history.history['val_' + metric])

# %%
TIMESTEPS = 250
FEATURES = 1
CODE_SIZE = 32
BATCH_SIZE = 256

# %% [markdown]
# # Data

# %% [markdown]
# # Pre-processing

# %%
# Download our time series 
timeseries = download('^SPX')['Close']
# Transform to log returns
timeseries = np.log(timeseries).diff().dropna()
timeseries
# Out:
# Date
# 1970-01-05    0.004934
# 1970-01-06   -0.006871
# 1970-01-07   -0.002049
# 1970-01-08    0.000540
# 1970-01-09   -0.003026
#                 ...
# 2024-08-20   -0.001987
# 2024-08-21    0.004231
# 2024-08-22   -0.008973
# 2024-08-23    0.011418
# 2024-08-26   -0.004131
# Name: Close, Length: 13782, dtype: float64

# %%
plot(timeseries)

# %%
X = timeseries.values

# remove outliers
outliers = np.quantile(np.abs(X), 0.99)
X = np.clip(X, -outliers, outliers)
print('Outliers', outliers)

# scale
X = X / outliers

plot(X)
# Out:
# Outliers 0.035878181362578504

# %%
# generate lags
X = window(X, TIMESTEPS).astype(np.float32)
y = timeseries[TIMESTEPS:]

x_train, x_test, y_train, y_test = split(X, y, 0.3)

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)

assert(np.isfinite(X).all() == True)
assert(np.isfinite(y).all() == True)
# Out:
# (9472, 250) (4060, 250)
# (9472,) (4060,)

# %%
evals = pd.DataFrame(index=['RMSE', 'MAE'])

def eval(name, y_pred, y_test):
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    evals[name] = [ rmse, mae ]

# %%
# Base cases
eval('Persistence', y_test.shift(1).fillna(0), y_test)
eval('Zero', np.zeros(len(y_test)), y_test)
eval('Mean', np.full(len(y_test), np.mean(x_train[:, -1])), y_test)
evals
# Out:
#       Persistence      Zero      Mean
# RMSE     0.019129  0.012773  0.015133
# MAE      0.012069  0.008113  0.010991

# %%
# Linear Regression
model = LinearRegression()
model.fit(x_train, y_train)
eval('LR', model.predict(x_test), y_test)

# %%
# # ARIMA
# import pmdarima as pm
# model = pm.auto_arima(x_train[:, -1], stationary=True, maxiter=5)
# eval('ARIMA', model.predict(len(x_test)), y_test)

# %%
def build_lstm(input_shape):
    input = Input(shape=input_shape)
    x = LSTM(64, return_sequences=True)(input)
    x = LSTM(64, return_sequences=False)(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation="linear")(x)
    return Model(input, x)

model = build_lstm((TIMESTEPS, FEATURES))
model.compile(loss='mse', metrics=['mae'])

history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=5, validation_data=(x_test, y_test))
plot_training(history, 'mae')

eval('LSTM', model.predict(x_test), y_test)
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Epoch 1/5
# 2024-08-26 17:02:46.088301: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 37/37 [==============================] - 5s 96ms/step - loss: 1.7049e-04 - mae: 0.0092 - val_loss: 1.7465e-04 - val_mae: 0.0086
# Epoch 2/5
# 37/37 [==============================] - 3s 83ms/step - loss: 1.1860e-04 - mae: 0.0079 - val_loss: 1.6442e-04 - val_mae: 0.0081
# Epoch 3/5
# 37/37 [==============================] - 3s 82ms/step - loss: 1.1175e-04 - mae: 0.0076 - val_loss: 1.7728e-04 - val_mae: 0.0087
# Epoch 4/5
# 37/37 [==============================] - 3s 82ms/step - loss: 1.0857e-04 - mae: 0.0075 - val_loss: 1.7356e-04 - val_mae: 0.0085
# Epoch 5/5
# 37/37 [==============================] - 3s 82ms/step - loss: 1.0634e-04 - mae: 0.0074 - val_loss: 1.7019e-04 - val_mae: 0.0087
# 127/127 [==============================] - 2s 12ms/step

# %%
evals
# Out:
#       Persistence      Zero      Mean        LR      LSTM
# RMSE     0.019129  0.012773  0.015133  0.013049  0.013046
# MAE      0.012069  0.008113  0.010991  0.008356  0.008664

# %% [markdown]
# # Data Generation

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data, batch_size=32, shuffle=True, timesteps=TIMESTEPS):
        self.timesteps = timesteps
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.data = data
        self.indexes = np.arange(len(self.data) - (timesteps * 1) - timesteps)
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return len(self.indexes) // self.batch_size
    
    def get_window(self, idx):
        return self.data[idx:idx+self.timesteps, 0]
    
    def __getitem__(self, batch):
        'Generate one batch of data'
        x = []
        y = []
        labels = []
        
        indexes = self.indexes[batch*self.batch_size//2:(batch+1)*self.batch_size//2]

        for idx in indexes:
            x_positive = self.get_window(idx)
            y_positive = self.get_window(idx + self.timesteps)
            y_negative = np.random.normal(np.mean(x_positive), np.std(x_positive), len(x_positive))

            # positive sample
            x.append(x_positive)
            y.append(y_positive)
            labels.append(1)

            # negative sample
            x.append(x_positive)
            y.append(y_negative)
            labels.append(0)
        
        x = np.array(x).astype(np.float32)
        y = np.array(y).astype(np.float32)
        labels = np.array(labels).astype(np.float32)

        x = np.expand_dims(x, axis=-1)
        y = np.expand_dims(y, axis=-1)
        
        return (x, y), labels

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
# Test generator
dg = DataGenerator(x_train, batch_size=BATCH_SIZE, shuffle=True)
print('Batches:', len(dg))

# Get the first batch
(bx, by), labels = dg.__getitem__(0)
print(f"x shape: {bx.shape}, y shape: {by.shape}, labels shape: {labels.shape}")

plot_forecast(bx[0, :, 0], by[0, :, 0], by[1, :, 0])
# Out:
# Batches: 35
# x shape: (256, 250, 1), y shape: (256, 250, 1), labels shape: (256,)

# %% [markdown]
# # CPC Model Architecture

# %%
def build_encoder(input_shape, code_size):
    input = Input(shape=input_shape)
    x = Conv1D(64, 3, activation='relu', padding='same')(input)
    x = Conv1D(64, 3, activation='relu', padding='same')(x)
    # x = Flatten()(x)
    # x = Dropout(0.5)(x)
    x = Dense(code_size, activation='linear', name='encoder_embedding')(x)
    return Model(input, x, name='encoder')

encoder = build_encoder((TIMESTEPS, FEATURES), CODE_SIZE)
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 250, 1)]          0
#
#  conv1d (Conv1D)             (None, 250, 64)           256
#
#  conv1d_1 (Conv1D)           (None, 250, 64)           12352
#
#  encoder_embedding (Dense)   (None, 250, 32)           2080
#
# =================================================================
# Total params: 14,688
# Trainable params: 14,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def build_context(input_shape, code_size):
    '''Build the autoregressive model doing predictions'''
    input = Input(shape=input_shape)
    x = LSTM(128, return_sequences=True, name="context")(input)
    x = LSTM(128, return_sequences=True)(x)
    # x = LSTM(64, return_sequences=False, name="context")(input)
    x = Dense(code_size, activation="linear", name="preds")(x)
    return Model(input, x, name="context")

context = build_context((TIMESTEPS, CODE_SIZE), CODE_SIZE)
context.summary()
# Out:
# Model: "context"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 250, 32)]         0
#
#  context (LSTM)              (None, 250, 128)          82432
#
#  lstm_2 (LSTM)               (None, 250, 128)          131584
#
#  preds (Dense)               (None, 250, 32)           4128
#
# =================================================================
# Total params: 218,144
# Trainable params: 218,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_input = Input((TIMESTEPS, FEATURES))
x_encoded = encoder(x_input)

y_pred = context(x_encoded)
# y_pred = x_encoded[-1]

y_input = Input((TIMESTEPS, FEATURES))
y_encoded = encoder(y_input)

output = K.mean(y_encoded * y_pred, axis=-1)
output = K.mean(output, axis=-1, keepdims=True)  # along the temporal dimension
output = K.sigmoid(output)

model = Model(inputs=[x_input, y_input], outputs=output, name='CPC')
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["binary_accuracy"])
model.summary()
# Out:
# Model: "CPC"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 250, 1)]     0           []
#
#  input_8 (InputLayer)           [(None, 250, 1)]     0           []
#
#  encoder (Functional)           (None, 250, 32)      14688       ['input_8[0][0]',
#                                                                   'input_9[0][0]']
#
#  context (Functional)           (None, 250, 32)      218144      ['encoder[2][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 250, 32)     0           ['encoder[3][0]',
#  )                                                                'context[0][0]']
#
#  tf.math.reduce_mean_2 (TFOpLam  (None, 250)         0           ['tf.math.multiply_1[0][0]']
#  bda)
#
#  tf.math.reduce_mean_3 (TFOpLam  (None, 1)           0           ['tf.math.reduce_mean_2[0][0]']
#  bda)
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 1)           0           ['tf.math.reduce_mean_3[0][0]']
#
# ==================================================================================================
# Total params: 232,832
# Trainable params: 232,832
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_gen = DataGenerator(x_train, batch_size=BATCH_SIZE, shuffle=True)
test_gen = DataGenerator(x_test, batch_size=BATCH_SIZE, shuffle=True)

# %%
history = model.fit(train_gen, epochs=5, validation_data=test_gen)
# Out:
# Epoch 1/5
# 35/35 [==============================] - 10s 277ms/step - loss: 0.3241 - binary_accuracy: 0.8768 - val_loss: 0.4715 - val_binary_accuracy: 0.8176
# Epoch 2/5
# 35/35 [==============================] - 9s 269ms/step - loss: 0.3264 - binary_accuracy: 0.8657 - val_loss: 0.5270 - val_binary_accuracy: 0.8185
# Epoch 3/5
# 35/35 [==============================] - 10s 274ms/step - loss: 0.2898 - binary_accuracy: 0.8886 - val_loss: 0.4846 - val_binary_accuracy: 0.7785
# Epoch 4/5
# 35/35 [==============================] - 9s 271ms/step - loss: 0.2803 - binary_accuracy: 0.8865 - val_loss: 0.4549 - val_binary_accuracy: 0.8107
# Epoch 5/5
# 35/35 [==============================] - 9s 268ms/step - loss: 0.2539 - binary_accuracy: 0.9020 - val_loss: 0.5094 - val_binary_accuracy: 0.8194

# %%
plot_training(history, 'binary_accuracy')

# %%
encoder.save('encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Downstream Task

# %%
encoder = load_model('encoder.h5', compile=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Compute embeddings for each window
x_train_embeds = encoder.predict(x_train)[:, -1, :]
x_test_embeds = encoder.predict(x_test)[:, -1, :]
# Out:
# 296/296 [==============================] - 0s 1ms/step
# 127/127 [==============================] - 0s 3ms/step

# %%
plot(x_train_embeds)

# %%
# Normalize each embedding vector to unit norm
x_train_embeds = x_train_embeds / np.linalg.norm(x_train_embeds, axis=1, keepdims=True)
x_test_embeds = x_test_embeds / np.linalg.norm(x_test_embeds, axis=1, keepdims=True)

# %%
plot(x_train_embeds)

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# Apply t-SNE for visualization
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
embeddings_tsne = tsne.fit_transform(x_train_embeds)

# Apply K-means clustering
kmeans = KMeans(n_clusters=6)
clusters = kmeans.fit_predict(x_train_embeds)

# Visualize the clusters using the t-SNE embeddings
plt.figure(figsize=(8, 8))
plt.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], c=clusters, cmap='viridis', alpha=0.5)
plt.title('Cluster analysis of CPC embeddings')
plt.show()
# Out:
# /Users/antonykrymski/miniconda3/envs/tf/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
# Linear Regression with CPC embeddings
model = LinearRegression()
model.fit(x_train_embeds, y_train)
eval('CPC-LR', model.predict(x_test_embeds), y_test)

# %%
def build_dense(input_shape):
    input = Input(shape=input_shape)
    x = Dense(64, activation='relu')(input)
    x = Dropout(0.2)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(1, activation='linear')(x)
    return Model(input, x)

model = build_dense(CODE_SIZE)
model.compile(loss='mse', metrics=['mae'])
model.summary()

history = model.fit(x_train_embeds, y_train, batch_size=BATCH_SIZE, epochs=10, validation_data=(x_test_embeds, y_test))
plot_training(history, 'mae')

eval('CPC', model.predict(x_test_embeds), y_test)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32)]              0
#
#  dense_4 (Dense)             (None, 64)                2112
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,337
# Trainable params: 6,337
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 37/37 [==============================] - 1s 12ms/step - loss: 0.0035 - mae: 0.0414 - val_loss: 3.8156e-04 - val_mae: 0.0155
# Epoch 2/10
# 37/37 [==============================] - 0s 6ms/step - loss: 4.9367e-04 - mae: 0.0166 - val_loss: 1.8828e-04 - val_mae: 0.0094
# Epoch 3/10
# 37/37 [==============================] - 0s 6ms/step - loss: 1.8956e-04 - mae: 0.0103 - val_loss: 1.7066e-04 - val_mae: 0.0085
# Epoch 4/10
# 37/37 [==============================] - 0s 6ms/step - loss: 1.1680e-04 - mae: 0.0078 - val_loss: 1.6476e-04 - val_mae: 0.0082
# Epoch 5/10
# 37/37 [==============================] - 0s 6ms/step - loss: 1.0297e-04 - mae: 0.0072 - val_loss: 1.6380e-04 - val_mae: 0.0081
# Epoch 6/10
# 37/37 [==============================] - 0s 6ms/step - loss: 1.0064e-04 - mae: 0.0071 - val_loss: 1.6388e-04 - val_mae: 0.0082
# Epoch 7/10
# 37/37 [==============================] - 0s 6ms/step - loss: 9.9810e-05 - mae: 0.0070 - val_loss: 1.6359e-04 - val_mae: 0.0081
# Epoch 8/10
# 37/37 [==============================] - 0s 6ms/step - loss: 1.0006e-04 - mae: 0.0070 - val_loss: 1.6409e-04 - val_mae: 0.0081
# Epoch 9/10
# 37/37 [==============================] - 0s 6ms/step - loss: 9.9901e-05 - mae: 0.0070 - val_loss: 1.6377e-04 - val_mae: 0.0081
# Epoch 10/10
# 37/37 [==============================] - 0s 6ms/step - loss: 9.9542e-05 - mae: 0.0070 - val_loss: 1.6396e-04 - val_mae: 0.0081
# 127/127 [==============================] - 0s 2ms/step

# %%
evals
# Out:
#       Persistence      Zero      Mean        LR      LSTM    CPC-LR       CPC
# RMSE     0.019129  0.012773  0.015133  0.013049  0.013046  0.012871  0.012805
# MAE      0.012069  0.008113  0.010991  0.008356  0.008664  0.008171  0.008140

# %% [markdown]
# # Optimize Sharpe

# %%
train_returns = timeseries[TIMESTEPS-1:][:len(x_train)]
test_returns = timeseries[-len(x_test)-1:-1]

# %%
def sharpe_ratio(returns):
    mean_return = tf.reduce_mean(returns)
    std_return = tf.math.reduce_std(returns)
    # if (std_return <= 0): return 0.
    sharpe = mean_return / std_return
    return sharpe * np.sqrt(252.0)

def sharpe_loss(log_returns, allocations):
    portfolio_returns = log_returns[1:, 0] * allocations[:-1, 0]
    # Negative Sharpe ratio (to maximize it)
    return -sharpe_ratio(portfolio_returns)

def build_dense(input_shape):
    input = Input(shape=input_shape)
    x = Dense(32, activation='relu')(input)
    x = Dropout(0.3)(x)
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(1, activation='tanh')(x)
    return Model(input, x)

model = build_dense(CODE_SIZE)
model.compile(loss=sharpe_loss)
model.summary()

history = model.fit(x_train_embeds, train_returns, batch_size=32, epochs=100, validation_data=(x_test_embeds, test_returns))
plot_training(history, 'loss')
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 32)]              0
#
#  dense_52 (Dense)            (None, 32)                1056
#
#  dropout_35 (Dropout)        (None, 32)                0
#
#  dense_53 (Dense)            (None, 32)                1056
#
#  dropout_36 (Dropout)        (None, 32)                0
#
#  dense_54 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,145
# Trainable params: 2,145
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 296/296 [==============================] - 3s 7ms/step - loss: -0.3285 - val_loss: -1.5879
# Epoch 2/100
# 296/296 [==============================] - 2s 7ms/step - loss: -0.6712 - val_loss: -1.6429
# Epoch 3/100
# 296/296 [==============================] - 2s 8ms/step - loss: -0.4915 - val_loss: -1.6163
# Epoch 4/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5841 - val_loss: -1.5841
# Epoch 5/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5115 - val_loss: -1.5535
# Epoch 6/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6253 - val_loss: -1.6095
# Epoch 7/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5363 - val_loss: -1.4926
# Epoch 8/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5708 - val_loss: -1.5366
# Epoch 9/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5910 - val_loss: -1.5958
# Epoch 10/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6968 - val_loss: -1.6502
# Epoch 11/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6819 - val_loss: -1.6289
# Epoch 12/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6317 - val_loss: -1.6200
# Epoch 13/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.4515 - val_loss: -1.5956
# Epoch 14/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6094 - val_loss: -1.6280
# Epoch 15/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6887 - val_loss: -1.6378
# Epoch 16/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5984 - val_loss: -1.6280
# Epoch 17/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5046 - val_loss: -1.6473
# Epoch 18/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5570 - val_loss: -1.5870
# Epoch 19/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5205 - val_loss: -1.5704
# Epoch 20/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5522 - val_loss: -1.5979
# Epoch 21/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5635 - val_loss: -1.5861
# Epoch 22/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5816 - val_loss: -1.5397
# Epoch 23/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5320 - val_loss: -1.6065
# Epoch 24/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.4854 - val_loss: -1.5808
# Epoch 25/100
# 296/296 [==============================] - 2s 7ms/step - loss: -0.5253 - val_loss: -1.5125
# Epoch 26/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5811 - val_loss: -1.5282
# Epoch 27/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5046 - val_loss: -1.5241
# Epoch 28/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.4516 - val_loss: -1.4996
# Epoch 29/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5716 - val_loss: -1.5556
# Epoch 30/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5243 - val_loss: -1.5649
# Epoch 31/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5459 - val_loss: -1.5405
# Epoch 32/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5443 - val_loss: -1.5394
# Epoch 33/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5967 - val_loss: -1.5800
# Epoch 34/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7178 - val_loss: -1.6173
# Epoch 35/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5151 - val_loss: -1.4500
# Epoch 36/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6042 - val_loss: -1.5265
# Epoch 37/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6095 - val_loss: -1.5855
# Epoch 38/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5410 - val_loss: -1.5299
# Epoch 39/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5245 - val_loss: -1.5169
# Epoch 40/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5819 - val_loss: -1.4372
# Epoch 41/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5727 - val_loss: -1.4602
# Epoch 42/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5694 - val_loss: -1.5179
# Epoch 43/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5490 - val_loss: -1.4743
# Epoch 44/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5924 - val_loss: -1.5235
# Epoch 45/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5785 - val_loss: -1.5690
# Epoch 46/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5151 - val_loss: -1.4816
# Epoch 47/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5686 - val_loss: -1.5247
# Epoch 48/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6158 - val_loss: -1.5459
# Epoch 49/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5668 - val_loss: -1.4145
# Epoch 50/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6170 - val_loss: -1.4395
# Epoch 51/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.8440 - val_loss: -1.5689
# Epoch 52/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6040 - val_loss: -1.6302
# Epoch 53/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6031 - val_loss: -1.6452
# Epoch 54/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6045 - val_loss: -1.5552
# Epoch 55/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6654 - val_loss: -1.6463
# Epoch 56/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6771 - val_loss: -1.7255
# Epoch 57/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6289 - val_loss: -1.6892
# Epoch 58/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6405 - val_loss: -1.7368
# Epoch 59/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6274 - val_loss: -1.6515
# Epoch 60/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.8362 - val_loss: -1.6759
# Epoch 61/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5815 - val_loss: -1.7089
# Epoch 62/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.4803 - val_loss: -1.6490
# Epoch 63/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5262 - val_loss: -1.6629
# Epoch 64/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7133 - val_loss: -1.6453
# Epoch 65/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6992 - val_loss: -1.7095
# Epoch 66/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5950 - val_loss: -1.7177
# Epoch 67/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5852 - val_loss: -1.7030
# Epoch 68/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6260 - val_loss: -1.6892
# Epoch 69/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5630 - val_loss: -1.7012
# Epoch 70/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7161 - val_loss: -1.7126
# Epoch 71/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6524 - val_loss: -1.6737
# Epoch 72/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6120 - val_loss: -1.6574
# Epoch 73/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5764 - val_loss: -1.6438
# Epoch 74/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.8486 - val_loss: -1.6420
# Epoch 75/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5472 - val_loss: -1.6362
# Epoch 76/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6865 - val_loss: -1.6014
# Epoch 77/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5988 - val_loss: -1.6540
# Epoch 78/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6398 - val_loss: -1.5876
# Epoch 79/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6342 - val_loss: -1.6019
# Epoch 80/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7355 - val_loss: -1.6373
# Epoch 81/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6955 - val_loss: -1.6957
# Epoch 82/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7146 - val_loss: -1.5545
# Epoch 83/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6723 - val_loss: -1.6334
# Epoch 84/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.8215 - val_loss: -1.5119
# Epoch 85/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5516 - val_loss: -1.5572
# Epoch 86/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.3971 - val_loss: -1.5008
# Epoch 87/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7551 - val_loss: -1.2407
# Epoch 88/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7488 - val_loss: -1.5463
# Epoch 89/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.4773 - val_loss: -1.5526
# Epoch 90/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7622 - val_loss: -1.5912
# Epoch 91/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7322 - val_loss: -1.5900
# Epoch 92/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6894 - val_loss: -1.5970
# Epoch 93/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7062 - val_loss: -1.6445
# Epoch 94/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5367 - val_loss: -1.6153
# Epoch 95/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.6213 - val_loss: -1.5909
# Epoch 96/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.7766 - val_loss: -1.6183
# Epoch 97/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5625 - val_loss: -1.5757
# Epoch 98/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5317 - val_loss: -1.6164
# Epoch 99/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5834 - val_loss: -1.5870
# Epoch 100/100
# 296/296 [==============================] - 2s 6ms/step - loss: -0.5987 - val_loss: -1.5086

# %%
allocations = model.predict(x_test_embeds)[:, 0]
portfolio_returns = test_returns[1:] * allocations[:-1]


sharpe_ratio(test_returns[1:]).numpy(), sharpe_ratio(portfolio_returns).numpy()
# Out:
# 127/127 [==============================] - 0s 1ms/step
# (0.4625010356771534, 0.5430515890552791)

# %%
plot_timeseries(index=np.arange(len(x_test)-1), benchmark=np.cumsum(test_returns[1:]), strategy=np.cumsum(portfolio_returns))

# %%
plot(allocations)

# %%
from tensorflow.keras import optimizers, callbacks
from tensorflow.keras import models

# Define the model architecture
def create_model(input_shape):
    model = models.Sequential([
        Input(shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(1, activation='tanh')
        # layers.Lambda(lambda x: -tf.math.abs(x))
    ])
    return model

# Function to calculate Sharpe ratio
def sharpe_ratio(returns):
    mean_return = tf.reduce_mean(returns)
    std_return = tf.math.reduce_std(returns)
    sharpe = mean_return / std_return
    return sharpe * np.sqrt(252)  # Annualize Sharpe ratio

# Custom training loop with gradient ascent for a single batch
def train_step(model, log_returns, features, optimizer):
    with tf.GradientTape() as tape:
        allocations = model(features, training=True)  # Forward pass
        # Shift allocations back by one period
        portfolio_returns = log_returns[1:] * allocations[:-1, 0]
        # portfolio_returns = tf.reduce_sum(log_returns[1:] * allocations[:-1], axis=1)
        sharpe = sharpe_ratio(portfolio_returns)
        loss = -sharpe  # Negative Sharpe ratio (to maximize it)
    
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    # print(sharpe.shape, portfolio_returns.shape, allocations.shape)
    return sharpe

def train_rl(features, log_returns, epochs_per_step=1, lr=0.001, window_size=120):
    assert len(log_returns) == len(features)
    allocations = np.zeros_like(log_returns)
    
    model = create_model(features.shape[1])
    optimizer = optimizers.legacy.Adam(learning_rate=lr, clipnorm=1.0)
    
    train_sharpe_history = []
    test_sharpe_history = []

    # Rolling window online learning
    for i in range(window_size, len(log_returns), window_size):
        # Train the model up to the current window
        for epoch in range(epochs_per_step):
            sharpe = train_step(model, log_returns[:i], features[:i], optimizer)
            
        if i >= len(log_returns) - window_size:
            window_size = len(log_returns) - i
        
        # Predict next window
        allocations[i:i+window_size] = model.predict(features[i:i+window_size])[:, 0]

        # Shift allocations back by one period for testing as well
        sharpe_test = sharpe_ratio(log_returns[1:i+window_size] * allocations[:i+window_size-1])

        # Append Sharpe ratios to history
        train_sharpe_history.append(sharpe.numpy())  # Convert TensorFlow tensor to a NumPy array
        test_sharpe_history.append(sharpe_test.numpy())
        
        print(f'Step {i}/{len(log_returns)}, Train Sharpe: {sharpe:.4f}, Test Sharpe {sharpe_test:.4f}')

    return allocations, model, (train_sharpe_history, test_sharpe_history)

# %%
# features_scaled = scale_embs(features)
log_returns = timeseries.values

def compute_embeddings(x):
    x = window(x, TIMESTEPS, 1)
    return encoder.predict(np.array(x))[:, -1, :]

def scale_embs(x):
    x = x / np.linalg.norm(x, axis=1, keepdims=True)
    return x

features_s = scale_embs(compute_embeddings(timeseries.values))

print(features_s.shape, log_returns[TIMESTEPS:].shape)

allocations, model, history = train_rl(features_s, log_returns[TIMESTEPS:], epochs_per_step=1, lr=0.0001, window_size=120)
# Out:
# 423/423 [==============================] - 2s 4ms/step
# (13531, 32) (13531,)
# 4/4 [==============================] - 0s 41ms/step
# Step 120/13531, Train Sharpe: 3.6757, Test Sharpe -0.1479
# 4/4 [==============================] - 0s 27ms/step
# Step 240/13531, Train Sharpe: 1.2199, Test Sharpe 0.9337
# 4/4 [==============================] - 0s 22ms/step
# Step 360/13531, Train Sharpe: 2.0065, Test Sharpe 0.9739
# 4/4 [==============================] - 0s 25ms/step
# Step 480/13531, Train Sharpe: 1.8284, Test Sharpe 0.4060
# 4/4 [==============================] - 0s 18ms/step
# Step 600/13531, Train Sharpe: 1.1034, Test Sharpe 0.3673
# 4/4 [==============================] - 0s 16ms/step
# Step 720/13531, Train Sharpe: 0.7644, Test Sharpe -0.0357
# 4/4 [==============================] - 0s 16ms/step
# Step 840/13531, Train Sharpe: 0.5982, Test Sharpe -0.6321
# 4/4 [==============================] - 0s 15ms/step
# Step 960/13531, Train Sharpe: -0.3344, Test Sharpe -0.2524
# 4/4 [==============================] - 0s 17ms/step
# Step 1080/13531, Train Sharpe: 0.0122, Test Sharpe -0.2031
# 4/4 [==============================] - 0s 16ms/step
# Step 1200/13531, Train Sharpe: 0.0666, Test Sharpe 0.0380
# 4/4 [==============================] - 0s 16ms/step
# Step 1320/13531, Train Sharpe: 0.4240, Test Sharpe 0.0810
# 4/4 [==============================] - 0s 31ms/step
# Step 1440/13531, Train Sharpe: 0.5280, Test Sharpe 0.0355
# 4/4 [==============================] - 0s 23ms/step
# Step 1560/13531, Train Sharpe: 0.4884, Test Sharpe -0.0013
# 4/4 [==============================] - 0s 24ms/step
# Step 1680/13531, Train Sharpe: 0.4427, Test Sharpe -0.0640
# 4/4 [==============================] - 0s 18ms/step
# Step 1800/13531, Train Sharpe: 0.3477, Test Sharpe 0.0299
# 4/4 [==============================] - 0s 20ms/step
# Step 1920/13531, Train Sharpe: 0.4763, Test Sharpe 0.0027
# 4/4 [==============================] - 0s 22ms/step
# Step 2040/13531, Train Sharpe: 0.5233, Test Sharpe 0.0037
# 4/4 [==============================] - 0s 19ms/step
# Step 2160/13531, Train Sharpe: 0.5310, Test Sharpe 0.0666
# 4/4 [==============================] - 0s 21ms/step
# Step 2280/13531, Train Sharpe: 0.5925, Test Sharpe 0.1146
# 4/4 [==============================] - 0s 19ms/step
# Step 2400/13531, Train Sharpe: 0.4924, Test Sharpe 0.2117
# 4/4 [==============================] - 0s 41ms/step
# Step 2520/13531, Train Sharpe: 0.6138, Test Sharpe 0.2296
# 4/4 [==============================] - 0s 25ms/step
# Step 2640/13531, Train Sharpe: 0.5233, Test Sharpe 0.1940
# 4/4 [==============================] - 0s 16ms/step
# Step 2760/13531, Train Sharpe: 0.3891, Test Sharpe 0.1476
# 4/4 [==============================] - 0s 16ms/step
# Step 2880/13531, Train Sharpe: 0.3914, Test Sharpe 0.2047
# 4/4 [==============================] - 0s 24ms/step
# Step 3000/13531, Train Sharpe: 0.4070, Test Sharpe 0.2607
# 4/4 [==============================] - 0s 18ms/step
# Step 3120/13531, Train Sharpe: 0.4374, Test Sharpe 0.2757
# 4/4 [==============================] - 0s 22ms/step
# Step 3240/13531, Train Sharpe: 0.4675, Test Sharpe 0.2552
# 4/4 [==============================] - 0s 32ms/step
# Step 3360/13531, Train Sharpe: 0.4410, Test Sharpe 0.2655
# 4/4 [==============================] - 0s 27ms/step
# Step 3480/13531, Train Sharpe: 0.4596, Test Sharpe 0.2918
# 4/4 [==============================] - 0s 26ms/step
# Step 3600/13531, Train Sharpe: 0.4636, Test Sharpe 0.2906
# 4/4 [==============================] - 0s 18ms/step
# Step 3720/13531, Train Sharpe: 0.4884, Test Sharpe 0.3736
# 4/4 [==============================] - 0s 23ms/step
# Step 3840/13531, Train Sharpe: 0.6104, Test Sharpe 0.3988
# 4/4 [==============================] - 0s 20ms/step
# Step 3960/13531, Train Sharpe: 0.6598, Test Sharpe 0.4192
# 4/4 [==============================] - 0s 16ms/step
# Step 4080/13531, Train Sharpe: 0.6745, Test Sharpe 0.4582
# 4/4 [==============================] - 0s 33ms/step
# Step 4200/13531, Train Sharpe: 0.6994, Test Sharpe 0.3112
# 4/4 [==============================] - 0s 24ms/step
# Step 4320/13531, Train Sharpe: 0.5236, Test Sharpe 0.3210
# 4/4 [==============================] - 0s 29ms/step
# Step 4440/13531, Train Sharpe: 0.5455, Test Sharpe 0.3282
# 4/4 [==============================] - 0s 24ms/step
# Step 4560/13531, Train Sharpe: 0.5365, Test Sharpe 0.3571
# 4/4 [==============================] - 0s 21ms/step
# Step 4680/13531, Train Sharpe: 0.5629, Test Sharpe 0.3791
# 4/4 [==============================] - 0s 24ms/step
# Step 4800/13531, Train Sharpe: 0.5941, Test Sharpe 0.3746
# 4/4 [==============================] - 0s 19ms/step
# Step 4920/13531, Train Sharpe: 0.5780, Test Sharpe 0.3497
# 4/4 [==============================] - 0s 18ms/step
# Step 5040/13531, Train Sharpe: 0.5498, Test Sharpe 0.3757
# 4/4 [==============================] - 0s 24ms/step
# Step 5160/13531, Train Sharpe: 0.5652, Test Sharpe 0.3737
# 4/4 [==============================] - 0s 25ms/step
# Step 5280/13531, Train Sharpe: 0.5290, Test Sharpe 0.3836
# 4/4 [==============================] - 0s 20ms/step
# Step 5400/13531, Train Sharpe: 0.5383, Test Sharpe 0.3826
# 4/4 [==============================] - 0s 20ms/step
# Step 5520/13531, Train Sharpe: 0.5475, Test Sharpe 0.3886
# 4/4 [==============================] - 0s 26ms/step
# Step 5640/13531, Train Sharpe: 0.5539, Test Sharpe 0.3982
# 4/4 [==============================] - 0s 22ms/step
# Step 5760/13531, Train Sharpe: 0.5732, Test Sharpe 0.3786
# 4/4 [==============================] - 0s 24ms/step
# Step 5880/13531, Train Sharpe: 0.5563, Test Sharpe 0.3883
# 4/4 [==============================] - 0s 42ms/step
# Step 6000/13531, Train Sharpe: 0.5700, Test Sharpe 0.4046
# 4/4 [==============================] - 0s 47ms/step
# Step 6120/13531, Train Sharpe: 0.5712, Test Sharpe 0.4369
# 4/4 [==============================] - 0s 26ms/step
# Step 6240/13531, Train Sharpe: 0.5991, Test Sharpe 0.4598
# 4/4 [==============================] - 0s 31ms/step
# Step 6360/13531, Train Sharpe: 0.6329, Test Sharpe 0.4629
# 4/4 [==============================] - 0s 27ms/step
# Step 6480/13531, Train Sharpe: 0.6306, Test Sharpe 0.4970
# 4/4 [==============================] - 0s 23ms/step
# Step 6600/13531, Train Sharpe: 0.6521, Test Sharpe 0.5450
# 4/4 [==============================] - 0s 23ms/step
# Step 6720/13531, Train Sharpe: 0.6730, Test Sharpe 0.5425
# 4/4 [==============================] - 0s 25ms/step
# Step 6840/13531, Train Sharpe: 0.6782, Test Sharpe 0.5858
# 4/4 [==============================] - 0s 25ms/step
# Step 6960/13531, Train Sharpe: 0.7229, Test Sharpe 0.5697
# 4/4 [==============================] - 0s 23ms/step
# Step 7080/13531, Train Sharpe: 0.7131, Test Sharpe 0.5829
# 4/4 [==============================] - 0s 24ms/step
# Step 7200/13531, Train Sharpe: 0.6864, Test Sharpe 0.5955
# 4/4 [==============================] - 0s 24ms/step
# Step 7320/13531, Train Sharpe: 0.7070, Test Sharpe 0.5876
# 4/4 [==============================] - 0s 25ms/step
# Step 7440/13531, Train Sharpe: 0.7084, Test Sharpe 0.5537
# 4/4 [==============================] - 0s 24ms/step
# Step 7560/13531, Train Sharpe: 0.7166, Test Sharpe 0.5311
# 4/4 [==============================] - 0s 26ms/step
# Step 7680/13531, Train Sharpe: 0.7070, Test Sharpe 0.4892
# 4/4 [==============================] - 0s 24ms/step
# Step 7800/13531, Train Sharpe: 0.7113, Test Sharpe 0.4759
# 4/4 [==============================] - 0s 26ms/step
# Step 7920/13531, Train Sharpe: 0.7147, Test Sharpe 0.4098
# 4/4 [==============================] - 0s 24ms/step
# Step 8040/13531, Train Sharpe: 0.6426, Test Sharpe 0.4075
# 4/4 [==============================] - 0s 28ms/step
# Step 8160/13531, Train Sharpe: 0.6317, Test Sharpe 0.4246
# 4/4 [==============================] - 0s 24ms/step
# Step 8280/13531, Train Sharpe: 0.6574, Test Sharpe 0.4367
# 4/4 [==============================] - 0s 25ms/step
# Step 8400/13531, Train Sharpe: 0.6641, Test Sharpe 0.4256
# 4/4 [==============================] - 0s 24ms/step
# Step 8520/13531, Train Sharpe: 0.6579, Test Sharpe 0.4386
# 4/4 [==============================] - 0s 25ms/step
# Step 8640/13531, Train Sharpe: 0.6592, Test Sharpe 0.4392
# 4/4 [==============================] - 0s 24ms/step
# Step 8760/13531, Train Sharpe: 0.6582, Test Sharpe 0.4444
# 4/4 [==============================] - 0s 26ms/step
# Step 8880/13531, Train Sharpe: 0.6534, Test Sharpe 0.4418
# 4/4 [==============================] - 0s 23ms/step
# Step 9000/13531, Train Sharpe: 0.6557, Test Sharpe 0.4626
# 4/4 [==============================] - 0s 24ms/step
# Step 9120/13531, Train Sharpe: 0.6734, Test Sharpe 0.4581
# 4/4 [==============================] - 0s 25ms/step
# Step 9240/13531, Train Sharpe: 0.6500, Test Sharpe 0.4316
# 4/4 [==============================] - 0s 24ms/step
# Step 9360/13531, Train Sharpe: 0.6240, Test Sharpe 0.4168
# 4/4 [==============================] - 0s 25ms/step
# Step 9480/13531, Train Sharpe: 0.6218, Test Sharpe 0.3373
# 4/4 [==============================] - 0s 47ms/step
# Step 9600/13531, Train Sharpe: 0.5147, Test Sharpe 0.3326
# 4/4 [==============================] - 0s 26ms/step
# Step 9720/13531, Train Sharpe: 0.5059, Test Sharpe 0.3577
# 4/4 [==============================] - 0s 25ms/step
# Step 9840/13531, Train Sharpe: 0.5308, Test Sharpe 0.3493
# 4/4 [==============================] - 0s 24ms/step
# Step 9960/13531, Train Sharpe: 0.5206, Test Sharpe 0.3578
# 4/4 [==============================] - 0s 24ms/step
# Step 10080/13531, Train Sharpe: 0.5284, Test Sharpe 0.3659
# 4/4 [==============================] - 0s 25ms/step
# Step 10200/13531, Train Sharpe: 0.5331, Test Sharpe 0.3540
# 4/4 [==============================] - 0s 32ms/step
# Step 10320/13531, Train Sharpe: 0.4937, Test Sharpe 0.3602
# 4/4 [==============================] - 0s 24ms/step
# Step 10440/13531, Train Sharpe: 0.5111, Test Sharpe 0.3674
# 4/4 [==============================] - 0s 24ms/step
# Step 10560/13531, Train Sharpe: 0.5381, Test Sharpe 0.3785
# 4/4 [==============================] - 0s 24ms/step
# Step 10680/13531, Train Sharpe: 0.5576, Test Sharpe 0.3876
# 4/4 [==============================] - 0s 25ms/step
# Step 10800/13531, Train Sharpe: 0.5679, Test Sharpe 0.3960
# 4/4 [==============================] - 0s 26ms/step
# Step 10920/13531, Train Sharpe: 0.5922, Test Sharpe 0.3991
# 4/4 [==============================] - 0s 34ms/step
# Step 11040/13531, Train Sharpe: 0.5994, Test Sharpe 0.3978
# 4/4 [==============================] - 0s 61ms/step
# Step 11160/13531, Train Sharpe: 0.6100, Test Sharpe 0.3868
# 4/4 [==============================] - 0s 25ms/step
# Step 11280/13531, Train Sharpe: 0.6161, Test Sharpe 0.3819
# 4/4 [==============================] - 0s 25ms/step
# Step 11400/13531, Train Sharpe: 0.6177, Test Sharpe 0.3918
# 4/4 [==============================] - 0s 25ms/step
# Step 11520/13531, Train Sharpe: 0.6195, Test Sharpe 0.3981
# 4/4 [==============================] - 0s 26ms/step
# Step 11640/13531, Train Sharpe: 0.6257, Test Sharpe 0.4012
# 4/4 [==============================] - 0s 26ms/step
# Step 11760/13531, Train Sharpe: 0.6304, Test Sharpe 0.4144
# 4/4 [==============================] - 0s 26ms/step
# Step 11880/13531, Train Sharpe: 0.6457, Test Sharpe 0.4109
# 4/4 [==============================] - 0s 25ms/step
# Step 12000/13531, Train Sharpe: 0.6447, Test Sharpe 0.4002
# 4/4 [==============================] - 0s 43ms/step
# Step 12120/13531, Train Sharpe: 0.6329, Test Sharpe 0.4106
# 4/4 [==============================] - 0s 44ms/step
# Step 12240/13531, Train Sharpe: 0.6379, Test Sharpe 0.4161
# 4/4 [==============================] - 0s 44ms/step
# Step 12360/13531, Train Sharpe: 0.6466, Test Sharpe 0.4035
# 4/4 [==============================] - 0s 25ms/step
# Step 12480/13531, Train Sharpe: 0.6417, Test Sharpe 0.4110
# 4/4 [==============================] - 0s 46ms/step
# Step 12600/13531, Train Sharpe: 0.6597, Test Sharpe 0.4240
# 4/4 [==============================] - 0s 25ms/step
# Step 12720/13531, Train Sharpe: 0.6668, Test Sharpe 0.4349
# 4/4 [==============================] - 0s 46ms/step
# Step 12840/13531, Train Sharpe: 0.6805, Test Sharpe 0.4198
# 4/4 [==============================] - 0s 43ms/step
# Step 12960/13531, Train Sharpe: 0.6780, Test Sharpe 0.4096
# 4/4 [==============================] - 0s 26ms/step
# Step 13080/13531, Train Sharpe: 0.6906, Test Sharpe 0.4205
# 4/4 [==============================] - 0s 26ms/step
# Step 13200/13531, Train Sharpe: 0.6989, Test Sharpe 0.4219
# 4/4 [==============================] - 0s 25ms/step
# Step 13320/13531, Train Sharpe: 0.6874, Test Sharpe 0.4346
# 3/3 [==============================] - 0s 54ms/step
# Step 13440/13531, Train Sharpe: 0.6961, Test Sharpe 0.4403

# %%
plt.figure(figsize=(10, 6))
plt.plot(history[0], label='Train Sharpe Ratio', color='blue')
plt.plot(history[1], label='Test Sharpe Ratio', color='red')
plt.xlabel('Steps')
plt.ylabel('Sharpe Ratio')
plt.title('Sharpe Ratio History')
plt.legend()
plt.show()

# %%
portfolio_returns = log_returns[1+TIMESTEPS:] * allocations[:-1]


sharpe_ratio(log_returns[1:]).numpy(), sharpe_ratio(portfolio_returns).numpy()
# Out:
# (0.43478016352832805, 0.44033211734821803)

# %%
plot(allocations)

# %%
print(log_returns.shape, allocations.shape)

test_idx = int(len(log_returns) * 0.5)
test_idx = 0

a = log_returns[1+TIMESTEPS:]

print(f'Benchmark Sharpe Ratio: {sharpe_ratio(log_returns[1+TIMESTEPS+test_idx:])}')
print(f'Strategy Sharpe Ratio: {sharpe_ratio(portfolio_returns[test_idx:])}')

plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(log_returns[1+TIMESTEPS+test_idx:]), label='Benchmark', color='blue')
plt.plot(np.cumsum(portfolio_returns[test_idx:]*10), label='Strategy', color='red')
plt.legend()
# Out:
# (13781,) (13531,)
# Benchmark Sharpe Ratio: 0.4434990727120904
# Strategy Sharpe Ratio: 0.44033211734821803

# %%
train_returns = timeseries[TIMESTEPS-1:][:len(x_train)]
test_returns = timeseries[-len(x_test)-1:-1]

# %%
def sharpe_ratio(returns):
    mean_return = tf.reduce_mean(returns)
    std_return = tf.math.reduce_std(returns)
    # if (std_return <= 0): return 0.
    sharpe = mean_return / std_return
    return sharpe * np.sqrt(252.0)

def sharpe_loss(log_returns, allocations):
    portfolio_returns = log_returns[1:, 0] * allocations[:-1, 0]
    # Negative Sharpe ratio (to maximize it)
    return -sharpe_ratio(portfolio_returns)

def build_dense(input_shape):
    input = Input(shape=input_shape)
    x = Dense(64, activation='relu')(input)
    x = Dropout(0.3)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(1, activation='tanh')(x)
    return Model(input, x)

model = build_dense(x_train.shape[1:])
model.compile(loss=sharpe_loss)
model.summary()

history = model.fit(x_train, train_returns, batch_size=8, epochs=10, validation_data=(x_test, test_returns))
plot_training(history, 'loss')
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_30 (InputLayer)       [(None, 250)]             0
#
#  dense_59 (Dense)            (None, 64)                16064
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_60 (Dense)            (None, 64)                4160
#
#  dropout_39 (Dropout)        (None, 64)                0
#
#  dense_61 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 20,289
# Trainable params: 20,289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1184/1184 [==============================] - 9s 7ms/step - loss: -0.4344 - val_loss: -2.0483
# Epoch 2/10
# 1184/1184 [==============================] - 8s 6ms/step - loss: -0.8488 - val_loss: -2.0898
# Epoch 3/10
# 1184/1184 [==============================] - 9s 7ms/step - loss: -0.8071 - val_loss: -2.0578
# Epoch 4/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.8217 - val_loss: -2.0682
# Epoch 5/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.8498 - val_loss: -2.0758
# Epoch 6/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.8229 - val_loss: -1.8127
# Epoch 7/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.9408 - val_loss: -1.9077
# Epoch 8/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.8338 - val_loss: -2.0761
# Epoch 9/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.9973 - val_loss: -2.0246
# Epoch 10/10
# 1184/1184 [==============================] - 7s 6ms/step - loss: -0.7080 - val_loss: -2.0488

# %%
allocations = model.predict(x_test)[:, 0]
portfolio_returns = test_returns[1:] * allocations[:-1]


sharpe_ratio(test_returns[1:]).numpy(), sharpe_ratio(portfolio_returns).numpy()
# Out:
# 127/127 [==============================] - 0s 2ms/step
# (0.451801950727601, 0.43543670295032216)

# %%
plot_timeseries(index=np.arange(len(x_test)-1), benchmark=np.cumsum(test_returns[1:]), strategy=np.cumsum(portfolio_returns))

# %%
plot(allocations)
